# %%
import numpy as np  # for numerical calculation
import pandas as pd # for data analysus
import matplotlib.pyplot as plt # for data visualization
import seaborn as sb # data visualization

from statsmodels.tsa.seasonal import seasonal_decompose # to find data as trend or seasonal
from statsmodels.tsa.api import SimpleExpSmoothing #for bulding simple exp smoothing (when no trend and seasonal)
from statsmodels.tsa.api import ExponentialSmoothing #for building double  and triple exp smoothing

import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('DS3_C1_S2_Store_Item_Sales_Data_Challenge.csv', parse_dates=['date'])
df.head() # dataset
# Out:
#         date  store  item  sales
# 0 2013-01-01      1     1     13
# 1 2013-01-02      1     1     11
# 2 2013-01-03      1     1     14
# 3 2013-01-04      1     1     13
# 4 2013-01-05      1     1     10

# %%
df= pd.read_csv('DS3_C1_S2_Store_Item_Sales_Data_Challenge.csv',parse_dates=['date'])

# %%
df=pd.read_csv('DS3_C1_S2_Store_Item_Sales_Data_Challenge.csv',parse_dates=['date'])

# %%
df.set_index('date',inplace=True)

# %%
df.set_index('date',inplace=True)

# %%
df.head(3)
# Out:
#             store  item  sales
# date
# 2013-01-01      1     1     13
# 2013-01-02      1     1     11
# 2013-01-03      1     1     14

# %%
df.set_index('date',inplace = True) #converting date into index form

# %%
df.head()
# Out:
#             store  item  sales
# date
# 2013-01-01      1     1     13
# 2013-01-02      1     1     11
# 2013-01-03      1     1     14
# 2013-01-04      1     1     13
# 2013-01-05      1     1     10

# %%
df.shape
# Out:
# (913000, 4)

# %%
df.shape
# Out:
# (913000, 3)

# %%
df.columns
# Out:
# Index(['store', 'item', 'sales'], dtype='object')

# %%
df.shape #size of the data
# Out:
# (913000, 3)

# %%
salse=df[['sales']]

# %%
sales
# Out:
#             sales
# date
# 2013-01-01     13
# 2013-01-02     11
# 2013-01-03     14
# 2013-01-04     13
# 2013-01-05     10
# ...           ...
# 2017-12-27     63
# 2017-12-28     59
# 2017-12-29     74
# 2017-12-30     62
# 2017-12-31     82
#
# [913000 rows x 1 columns]

# %%
sales=df[['sales']]
sales
# Out:
#         sales
# 0          13
# 1          11
# 2          14
# 3          13
# 4          10
# ...       ...
# 912995     63
# 912996     59
# 912997     74
# 912998     62
# 912999     82
#
# [913000 rows x 1 columns]

# %%
s=df[['sales']]

# %%
sale = df[['sales']] # fetching sales data

# %%
plt.figure(figsize=(16,7))
plt.plot(sales)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 plt.figure(figsize=(16,7))
# ----> 2 plt.plot(sales)
#
# NameError: name 'sales' is not defined

# %%
plt.figure(figsize=(20,8))
plt.plot(s) #visualization

# %% [markdown]
# # Task 2

# %%
decomposition = seasonal_decompose(sales,period=365) 
#period = 365 due the data is in day
d_seasonal = decomposition.seasonal
d_trend = decomposition.trend
d_residual = decomposition.resid

# %%
d=seasonal_decompose(sale,period=365)
d_seasonal=d.seasonal
d_trend=d.trend
d_residual=d.resid

# %%
w=seasonal_decompose(s,period=365)
d_trend=w.trend
d_seasonal=w.seasonal
d_residual=w.resid

# %%
s=seasonal_decompose(sales,period=365)
d_season=s.seasonal
d_trend=s.trend
d_residual=s.resid

# %%
fig,ac=plt.subplots(4,1,figsize=(18,7))
plt.subplot(411)
plt.plot(sale,label='orginal')
plt.legend(loc='best')


plt.subplot(412)
plt.plot(sale,label='seasonal')
plt.legend(loc='best')



plt.subplot(413)
plt.plot(sale,label='trend')
plt.legend(loc='best')


plt.subplot(414)
plt.plt(sale,label='residual')
plt.legend('best')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 19
#      15 plt.legend(loc='best')
#      18 plt.subplot(414)
# ---> 19 plt.plt(sale,label='residual')
#      20 plt.legend('best')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'plt'

# %%
fig,ax=plt.subplots(4,1,figsize=(20,12))
plt.subplot(411)
plt.plot(sales,label='orginal')
plt.legend(loc='best')

plt.subplot(411)
plt.plot(sales,label='seasonal')
plt.legend(loc='best')


plt.subplot(413)
plt.plot(sales,label= ' trend')
plt.legend(loc='best')


plt.subplot(413)
plt.subplot(sales,label='residual')
plt.legend(loc='best')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 17
#      13 plt.legend(loc='best')
#      16 plt.subplot(413)
# ---> 17 plt.subplot(sales,label='residual')
#      18 plt.legend(loc='best')
#
# File ~\anaconda3\New folder\lib\site-packages\matplotlib\pyplot.py:1296, in subplot(*args, **kwargs)
#    1293 fig = gcf()
#    1295 # First, search for an existing subplot with a matching spec.
# -> 1296 key = SubplotSpec._from_subplot_args(fig, args)
#    1298 for ax in fig.axes:
#    1299     # if we found an Axes at the position sort out if we can re-use it
#    1300     if ax.get_subplotspec() == key:
#    1301         # if the user passed no kwargs, re-use
#
# File ~\anaconda3\New folder\lib\site-packages\matplotlib\gridspec.py:569, in SubplotSpec._from_subplot_args(figure, args)
#     567     return arg
#     568 elif not isinstance(arg, Integral):
# --> 569     raise ValueError(
#     570         f"Single argument to subplot must be a three-digit "
#     571         f"integer, not {arg!r}")
#     572 try:
#     573     rows, cols, num = map(int, str(arg))
#
# ValueError: Single argument to subplot must be a three-digit integer, not             sales
# date
# 2013-01-01     13
# 2013-01-02     11
# 2013-01-03     14
# 2013-01-04     13
# 2013-01-05     10
# ...           ...
# 2017-12-27     63
# 2017-12-28     59
# 2017-12-29     74
# 2017-12-30     62
# 2017-12-31     82
#
# [913000 rows x 1 columns]

# %%
decomposition=seasonal_decompose(sales,period=365)

# %%
fig,ax=plt.subplots(4,1,figsize=(17,8))
plt.subplot(411)
plt.plot(s,label='orginal')
plt.legend(loc='best')

plt.subplot(412)
plt.plot(d_seasonal,label='seasonal')
plt.legend(loc='best')


plt.subplot(413)
plt.plot(d_trend,label='trend')
plt.legend(loc='best')


plt.subplot(414)
plt.plot(d_residual,label='residual')
plt.legend(loc='best')

# %%
fig,ax = plt.subplots(4,1, figsize= (20,12))

plt.subplot(411)
plt.plot(sale, label= 'orginal')
plt.legend(loc='best')

plt.subplot(412)
plt.plot(d_seasonal,label='seasonal')
plt.legend(loc='best')

plt.subplot(413)
plt.plot(d_trend,label= ' trend')
plt.legend(loc='best')

plt.subplot(414)
plt.plot(d_residual,label='residual')
plt.legend(loc='best')

# %% [markdown]
# we can find any interpretation from this data

# %%
resample=df['sales'].resample('M').mean()

# %%
resample=df['sales'].resample('M').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 resample=df['sales'].resample('M').mean()
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\series.py:5872, in Series.resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset, group_keys)
#    5855 @doc(NDFrame.resample, **_shared_doc_kwargs)  # type: ignore[has-type]
#    5856 def resample(
#    5857     self,
#    (...)
#    5870     group_keys: bool | lib.NoDefault = no_default,
#    5871 ) -> Resampler:
# -> 5872     return super().resample(
#    5873         rule=rule,
#    5874         axis=axis,
#    5875         closed=closed,
#    5876         label=label,
#    5877         convention=convention,
#    5878         kind=kind,
#    5879         loffset=loffset,
#    5880         base=base,
#    5881         on=on,
#    5882         level=level,
#    5883         origin=origin,
#    5884         offset=offset,
#    5885         group_keys=group_keys,
#    5886     )
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\generic.py:8858, in NDFrame.resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset, group_keys)
#    8855 from pandas.core.resample import get_resampler
#    8857 axis = self._get_axis_number(axis)
# -> 8858 return get_resampler(
#    8859     self,
#    8860     freq=rule,
#    8861     label=label,
#    8862     closed=closed,
#    8863     axis=axis,
#    8864     kind=kind,
#    8865     loffset=loffset,
#    8866     convention=convention,
#    8867     base=base,
#    8868     key=on,
#    8869     level=level,
#    8870     origin=origin,
#    8871     offset=offset,
#    8872     group_keys=group_keys,
#    8873 )
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\resample.py:1544, in get_resampler(obj, kind, **kwds)
#    1540 """
#    1541 Create a TimeGrouper and return our resampler.
#    1542 """
#    1543 tg = TimeGrouper(**kwds)
# -> 1544 return tg._get_resampler(obj, kind=kind)
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\resample.py:1725, in TimeGrouper._get_resampler(self, obj, kind)
#    1720 elif isinstance(ax, TimedeltaIndex):
#    1721     return TimedeltaIndexResampler(
#    1722         obj, groupby=self, axis=self.axis, group_keys=self.group_keys
#    1723     )
# -> 1725 raise TypeError(
#    1726     "Only valid with DatetimeIndex, "
#    1727     "TimedeltaIndex or PeriodIndex, "
#    1728     f"but got an instance of '{type(ax).__name__}'"
#    1729 )
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'RangeIndex'

# %%
resample=df['sales'].resample('M').mean() #resampling
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 resample=df['sales'].resample('M').mean()
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\series.py:5872, in Series.resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset, group_keys)
#    5855 @doc(NDFrame.resample, **_shared_doc_kwargs)  # type: ignore[has-type]
#    5856 def resample(
#    5857     self,
#    (...)
#    5870     group_keys: bool | lib.NoDefault = no_default,
#    5871 ) -> Resampler:
# -> 5872     return super().resample(
#    5873         rule=rule,
#    5874         axis=axis,
#    5875         closed=closed,
#    5876         label=label,
#    5877         convention=convention,
#    5878         kind=kind,
#    5879         loffset=loffset,
#    5880         base=base,
#    5881         on=on,
#    5882         level=level,
#    5883         origin=origin,
#    5884         offset=offset,
#    5885         group_keys=group_keys,
#    5886     )
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\generic.py:8858, in NDFrame.resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset, group_keys)
#    8855 from pandas.core.resample import get_resampler
#    8857 axis = self._get_axis_number(axis)
# -> 8858 return get_resampler(
#    8859     self,
#    8860     freq=rule,
#    8861     label=label,
#    8862     closed=closed,
#    8863     axis=axis,
#    8864     kind=kind,
#    8865     loffset=loffset,
#    8866     convention=convention,
#    8867     base=base,
#    8868     key=on,
#    8869     level=level,
#    8870     origin=origin,
#    8871     offset=offset,
#    8872     group_keys=group_keys,
#    8873 )
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\resample.py:1544, in get_resampler(obj, kind, **kwds)
#    1540 """
#    1541 Create a TimeGrouper and return our resampler.
#    1542 """
#    1543 tg = TimeGrouper(**kwds)
# -> 1544 return tg._get_resampler(obj, kind=kind)
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\resample.py:1725, in TimeGrouper._get_resampler(self, obj, kind)
#    1720 elif isinstance(ax, TimedeltaIndex):
#    1721     return TimedeltaIndexResampler(
#    1722         obj, groupby=self, axis=self.axis, group_keys=self.group_keys
#    1723     )
# -> 1725 raise TypeError(
#    1726     "Only valid with DatetimeIndex, "
#    1727     "TimedeltaIndex or PeriodIndex, "
#    1728     f"but got an instance of '{type(ax).__name__}'"
#    1729 )
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'RangeIndex'

# %%
resample=df['sales'].resample('M').mean()

# %%
b=pd.DataFrame(resample)

# %%
resample=pd.DataFrame(resample)

# %%
m=pd.DataFrame(resample)

# %%
m
# Out:
#                 sales
# date
# 2013-01-31  29.348645
# 2013-02-28  32.815500
# 2013-03-31  39.831097
# 2013-04-30  45.484933
# 2013-05-31  49.241419
# 2013-06-30  53.039800
# 2013-07-31  55.220774
# 2013-08-31  49.468452
# 2013-09-30  45.993800
# 2013-10-31  42.360452
# 2013-11-30  46.176200
# 2013-12-31  32.684323
# 2014-01-31  33.934645
# 2014-02-28  37.794071
# 2014-03-31  45.438774
# 2014-04-30  52.594267
# 2014-05-31  56.959806
# 2014-06-30  60.456133
# 2014-07-31  63.807097
# 2014-08-31  57.135226
# 2014-09-30  52.341600
# 2014-10-31  48.960194
# 2014-11-30  53.385533
# 2014-12-31  37.293419
# 2015-01-31  35.646000
# 2015-02-28  39.379786
# 2015-03-31  47.158129
# 2015-04-30  54.964467
# 2015-05-31  59.800129
# 2015-06-30  62.478933
# 2015-07-31  66.925806
# 2015-08-31  59.380710
# 2015-09-30  54.888800
# 2015-10-31  51.435677
# 2015-11-30  55.176333
# 2015-12-31  39.198194
# 2016-01-31  38.867032
# 2016-02-29  42.410828
# 2016-03-31  51.024581
# 2016-04-30  60.130000
# 2016-05-31  63.789032
# 2016-06-30  68.177600
# 2016-07-31  73.465677
# 2016-08-31  63.322194
# 2016-09-30  59.788733
# 2016-10-31  55.718516
# 2016-11-30  59.429867
# 2016-12-31  42.800710
# 2017-01-31  39.826194
# 2017-02-28  44.383500
# 2017-03-31  53.075290
# 2017-04-30  62.590800
# 2017-05-31  65.850710
# 2017-06-30  70.974933
# 2017-07-31  75.573742
# 2017-08-31  66.219548
# 2017-09-30  62.350867
# 2017-10-31  57.494194
# 2017-11-30  61.922467
# 2017-12-31  44.849677

# %%
resample
# Out:
#                 sales
# date
# 2013-01-31  29.348645
# 2013-02-28  32.815500
# 2013-03-31  39.831097
# 2013-04-30  45.484933
# 2013-05-31  49.241419
# 2013-06-30  53.039800
# 2013-07-31  55.220774
# 2013-08-31  49.468452
# 2013-09-30  45.993800
# 2013-10-31  42.360452
# 2013-11-30  46.176200
# 2013-12-31  32.684323
# 2014-01-31  33.934645
# 2014-02-28  37.794071
# 2014-03-31  45.438774
# 2014-04-30  52.594267
# 2014-05-31  56.959806
# 2014-06-30  60.456133
# 2014-07-31  63.807097
# 2014-08-31  57.135226
# 2014-09-30  52.341600
# 2014-10-31  48.960194
# 2014-11-30  53.385533
# 2014-12-31  37.293419
# 2015-01-31  35.646000
# 2015-02-28  39.379786
# 2015-03-31  47.158129
# 2015-04-30  54.964467
# 2015-05-31  59.800129
# 2015-06-30  62.478933
# 2015-07-31  66.925806
# 2015-08-31  59.380710
# 2015-09-30  54.888800
# 2015-10-31  51.435677
# 2015-11-30  55.176333
# 2015-12-31  39.198194
# 2016-01-31  38.867032
# 2016-02-29  42.410828
# 2016-03-31  51.024581
# 2016-04-30  60.130000
# 2016-05-31  63.789032
# 2016-06-30  68.177600
# 2016-07-31  73.465677
# 2016-08-31  63.322194
# 2016-09-30  59.788733
# 2016-10-31  55.718516
# 2016-11-30  59.429867
# 2016-12-31  42.800710
# 2017-01-31  39.826194
# 2017-02-28  44.383500
# 2017-03-31  53.075290
# 2017-04-30  62.590800
# 2017-05-31  65.850710
# 2017-06-30  70.974933
# 2017-07-31  75.573742
# 2017-08-31  66.219548
# 2017-09-30  62.350867
# 2017-10-31  57.494194
# 2017-11-30  61.922467
# 2017-12-31  44.849677

# %%
decomposition2= seasonal_decompose(resample,period=12)
d_seasonal2= decomposition2.seasonal
d_trend2= decomposition2.trend
d_residual2= decomposition2.resid

# %%
fig , ax = plt.subplots(4,1, figsize=(20,12))

plt.subplot(411)
plt.plot(resample,label= 'original')
plt.legend(loc='best')

plt.subplot(412)
plt.plot(d_seasonal2,label= 'seasonal')
plt.legend(loc= 'best')

plt.subplot(413)
plt.plot(d_trend2,label = 'trend')
plt.legend(loc = 'best')

plt.subplot(414)
plt.plot(d_residual2, label= 'residual')
plt.legend(loc = 'best')

# %% [markdown]
# After Resampling technique we can get some clear ploting

# %% [markdown]
# the data looks seasonal and trend

# %% [markdown]
# # Task 3
#     Stationarity Check

# %%
from statsmodels.tsa.stattools import adfuller # to check stationarity or not

# %%
def checkStationarity(df):
    pvalue=adfuller(df['sales'])[1]
    print(pvalue)
    if pvalue<0.05:
        mea='pvalue={}.data is stationary proceed to model building'.format(pvalue)
    else:
        mea='pvalue={}.data is not sationary make the data stationary before model building'
    return mea

# %%
def check(df):
    p=adfuller(df['sales'])[1]
    print(p)
    if p <0.05:
        me='p ={}. data is stationary  proceed to  model building'.format(p)
    else:
        me='p={}.data is not stationary proceed to model building '
    return me

# %%
def checkStationarity(data):
    pvalue = adfuller(data['sales'])[1]
    print(pvalue)
    
    if pvalue <0.05:
        msg = "pvalue= {}. Data is stationary. Proceed to model Building".format(pvalue)
    else:
        msg = 'pvalue= {}. Data is not stationary. Make the data Stationary before model building'.format(pvalue)
    return msg

# %%
checkStationarity(resample)
# Out:
# 3.692387626163412e-06
# 'pvalue= 3.692387626163412e-06. Data is stationary. Proceed to model Building'

# %%
data
# Out:
# date
# 2013-01-31    29.348645
# 2013-02-28    32.815500
# 2013-03-31    39.831097
# 2013-04-30    45.484933
# 2013-05-31    49.241419
# 2013-06-30    53.039800
# 2013-07-31    55.220774
# 2013-08-31    49.468452
# 2013-09-30    45.993800
# 2013-10-31    42.360452
# 2013-11-30    46.176200
# 2013-12-31    32.684323
# 2014-01-31    33.934645
# 2014-02-28    37.794071
# 2014-03-31    45.438774
# 2014-04-30    52.594267
# 2014-05-31    56.959806
# 2014-06-30    60.456133
# 2014-07-31    63.807097
# 2014-08-31    57.135226
# 2014-09-30    52.341600
# 2014-10-31    48.960194
# 2014-11-30    53.385533
# 2014-12-31    37.293419
# 2015-01-31    35.646000
# 2015-02-28    39.379786
# 2015-03-31    47.158129
# 2015-04-30    54.964467
# 2015-05-31    59.800129
# 2015-06-30    62.478933
# 2015-07-31    66.925806
# 2015-08-31    59.380710
# 2015-09-30    54.888800
# 2015-10-31    51.435677
# 2015-11-30    55.176333
# 2015-12-31    39.198194
# 2016-01-31    38.867032
# 2016-02-29    42.410828
# 2016-03-31    51.024581
# 2016-04-30    60.130000
# 2016-05-31    63.789032
# 2016-06-30    68.177600
# 2016-07-31    73.465677
# 2016-08-31    63.322194
# 2016-09-30    59.788733
# 2016-10-31    55.718516
# 2016-11-30    59.429867
# 2016-12-31    42.800710
# 2017-01-31    39.826194
# 2017-02-28    44.383500
# 2017-03-31    53.075290
# 2017-04-30    62.590800
# 2017-05-31    65.850710
# 2017-06-30    70.974933
# 2017-07-31    75.573742
# 2017-08-31    66.219548
# 2017-09-30    62.350867
# 2017-10-31    57.494194
# 2017-11-30    61.922467
# 2017-12-31    44.849677
# Freq: M, Name: sales, dtype: float64

# %% [markdown]
# # Task 4
#     Data Smoothing

# %% [markdown]
# # Simple Exponent Smoothing

# %%
def simplesmoothing(data,alpha):
    model = SimpleExpSmoothing(data).fit(smoothing_level=alpha,optimized=False)
    pdct = model.fittedvalues
    df = pd.DataFrame({'actual':data, 'forecast':pdct})
    return(model,df)

# %%
def simplesmoothing(data,alpha):
     model = SimpleExpSmoothing(data).fit(smoothing_level=alpha,optimized=False)
    pdct = model.fittedvalues
    df = pd.DataFrame({'actual':data, 'forecast':pdct})
    return(model,df)

# %%
a=17
print(a*100)
# Out:
# 1700

# %%
n=input('enter name')
for i in range(1,100):
    print(n)
# Out:
# enter nameanas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas
# anas

# %%
data= resample['sales']

# %%
d_simple_exp = {}
alphas = [0,0.2,0.6,0.8]

for a in alphas:
    model,df = simplesmoothing(data,a)
    d_simple_exp[a] = df.forecast

# %%
d_simple_exp
# Out:
# {0: date
#  2013-01-31    29.348645
#  2013-02-28    29.348645
#  2013-03-31    29.348645
#  2013-04-30    29.348645
#  2013-05-31    29.348645
#  2013-06-30    29.348645
#  2013-07-31    29.348645
#  2013-08-31    29.348645
#  2013-09-30    29.348645
#  2013-10-31    29.348645
#  2013-11-30    29.348645
#  2013-12-31    29.348645
#  2014-01-31    29.348645
#  2014-02-28    29.348645
#  2014-03-31    29.348645
#  2014-04-30    29.348645
#  2014-05-31    29.348645
#  2014-06-30    29.348645
#  2014-07-31    29.348645
#  2014-08-31    29.348645
#  2014-09-30    29.348645
#  2014-10-31    29.348645
#  2014-11-30    29.348645
#  2014-12-31    29.348645
#  2015-01-31    29.348645
#  2015-02-28    29.348645
#  2015-03-31    29.348645
#  2015-04-30    29.348645
#  2015-05-31    29.348645
#  2015-06-30    29.348645
#  2015-07-31    29.348645
#  2015-08-31    29.348645
#  2015-09-30    29.348645
#  2015-10-31    29.348645
#  2015-11-30    29.348645
#  2015-12-31    29.348645
#  2016-01-31    29.348645
#  2016-02-29    29.348645
#  2016-03-31    29.348645
#  2016-04-30    29.348645
#  2016-05-31    29.348645
#  2016-06-30    29.348645
#  2016-07-31    29.348645
#  2016-08-31    29.348645
#  2016-09-30    29.348645
#  2016-10-31    29.348645
#  2016-11-30    29.348645
#  2016-12-31    29.348645
#  2017-01-31    29.348645
#  2017-02-28    29.348645
#  2017-03-31    29.348645
#  2017-04-30    29.348645
#  2017-05-31    29.348645
#  2017-06-30    29.348645
#  2017-07-31    29.348645
#  2017-08-31    29.348645
#  2017-09-30    29.348645
#  2017-10-31    29.348645
#  2017-11-30    29.348645
#  2017-12-31    29.348645
#  Freq: M, Name: forecast, dtype: float64,
#  0.2: date
#  2013-01-31    29.348645
#  2013-02-28    29.348645
#  2013-03-31    30.042016
#  2013-04-30    31.999832
#  2013-05-31    34.696852
#  2013-06-30    37.605766
#  2013-07-31    40.692573
#  2013-08-31    43.598213
#  2013-09-30    44.772261
#  2013-10-31    45.016569
#  2013-11-30    44.485345
#  2013-12-31    44.823516
#  2014-01-31    42.395677
#  2014-02-28    40.703471
#  2014-03-31    40.121591
#  2014-04-30    41.185028
#  2014-05-31    43.466875
#  2014-06-30    46.165462
#  2014-07-31    49.023596
#  2014-08-31    51.980296
#  2014-09-30    53.011282
#  2014-10-31    52.877346
#  2014-11-30    52.093915
#  2014-12-31    52.352239
#  2015-01-31    49.340475
#  2015-02-28    46.601580
#  2015-03-31    45.157221
#  2015-04-30    45.557403
#  2015-05-31    47.438815
#  2015-06-30    49.911078
#  2015-07-31    52.424649
#  2015-08-31    55.324881
#  2015-09-30    56.136046
#  2015-10-31    55.886597
#  2015-11-30    54.996413
#  2015-12-31    55.032397
#  2016-01-31    51.865557
#  2016-02-29    49.265852
#  2016-03-31    47.894847
#  2016-04-30    48.520794
#  2016-05-31    50.842635
#  2016-06-30    53.431914
#  2016-07-31    56.381051
#  2016-08-31    59.797977
#  2016-09-30    60.502820
#  2016-10-31    60.360003
#  2016-11-30    59.431705
#  2016-12-31    59.431338
#  2017-01-31    56.105212
#  2017-02-28    52.849408
#  2017-03-31    51.156227
#  2017-04-30    51.540039
#  2017-05-31    53.750192
#  2017-06-30    56.170295
#  2017-07-31    59.131223
#  2017-08-31    62.419727
#  2017-09-30    63.179691
#  2017-10-31    63.013926
#  2017-11-30    61.909980
#  2017-12-31    61.912477
#  Freq: M, Name: forecast, dtype: float64,
#  0.6: date
#  2013-01-31    29.348645
#  2013-02-28    29.348645
#  2013-03-31    31.428758
#  2013-04-30    36.470161
#  2013-05-31    41.879025
#  2013-06-30    46.296461
#  2013-07-31    50.342465
#  2013-08-31    53.269450
#  2013-09-30    50.988851
#  2013-10-31    47.991820
#  2013-11-30    44.612999
#  2013-12-31    45.550920
#  2014-01-31    37.830961
#  2014-02-28    35.493172
#  2014-03-31    36.873712
#  2014-04-30    42.012749
#  2014-05-31    48.361660
#  2014-06-30    53.520548
#  2014-07-31    57.681899
#  2014-08-31    61.357018
#  2014-09-30    58.823943
#  2014-10-31    54.934537
#  2014-11-30    51.349931
#  2014-12-31    52.571292
#  2015-01-31    43.404569
#  2015-02-28    38.749427
#  2015-03-31    39.127642
#  2015-04-30    43.945934
#  2015-05-31    50.557054
#  2015-06-30    56.102899
#  2015-07-31    59.928520
#  2015-08-31    64.126892
#  2015-09-30    61.279182
#  2015-10-31    57.444953
#  2015-11-30    53.839388
#  2015-12-31    54.641555
#  2016-01-31    45.375538
#  2016-02-29    41.470435
#  2016-03-31    42.034670
#  2016-04-30    47.428617
#  2016-05-31    55.049447
#  2016-06-30    60.293198
#  2016-07-31    65.023839
#  2016-08-31    70.088942
#  2016-09-30    66.028893
#  2016-10-31    62.284797
#  2016-11-30    58.345029
#  2016-12-31    58.995931
#  2017-01-31    49.278798
#  2017-02-28    43.607235
#  2017-03-31    44.072994
#  2017-04-30    49.474372
#  2017-05-31    57.344229
#  2017-06-30    62.448117
#  2017-07-31    67.564207
#  2017-08-31    72.369928
#  2017-09-30    68.679700
#  2017-10-31    64.882400
#  2017-11-30    60.449476
#  2017-12-31    61.333270
#  Freq: M, Name: forecast, dtype: float64,
#  0.8: date
#  2013-01-31    29.348645
#  2013-02-28    29.348645
#  2013-03-31    32.122129
#  2013-04-30    38.289303
#  2013-05-31    44.045807
#  2013-06-30    48.202297
#  2013-07-31    52.072299
#  2013-08-31    54.591079
#  2013-09-30    50.492977
#  2013-10-31    46.893635
#  2013-11-30    43.267088
#  2013-12-31    45.594378
#  2014-01-31    35.266334
#  2014-02-28    34.200983
#  2014-03-31    37.075454
#  2014-04-30    43.766110
#  2014-05-31    50.828635
#  2014-06-30    55.733572
#  2014-07-31    59.511621
#  2014-08-31    62.948002
#  2014-09-30    58.297781
#  2014-10-31    53.532836
#  2014-11-30    49.874722
#  2014-12-31    52.683371
#  2015-01-31    40.371410
#  2015-02-28    36.591082
#  2015-03-31    38.822045
#  2015-04-30    45.490912
#  2015-05-31    53.069756
#  2015-06-30    58.454054
#  2015-07-31    61.673958
#  2015-08-31    65.875437
#  2015-09-30    60.679655
#  2015-10-31    56.046971
#  2015-11-30    52.357936
#  2015-12-31    54.612654
#  2016-01-31    42.281086
#  2016-02-29    39.549843
#  2016-03-31    41.838631
#  2016-04-30    49.187391
#  2016-05-31    57.941478
#  2016-06-30    62.619521
#  2016-07-31    67.065984
#  2016-08-31    72.185739
#  2016-09-30    65.094903
#  2016-10-31    60.849967
#  2016-11-30    56.744806
#  2016-12-31    58.892855
#  2017-01-31    46.019139
#  2017-02-28    41.064783
#  2017-03-31    43.719757
#  2017-04-30    51.204184
#  2017-05-31    60.313477
#  2017-06-30    64.743263
#  2017-07-31    69.728599
#  2017-08-31    74.404713
#  2017-09-30    67.856581
#  2017-10-31    63.452010
#  2017-11-30    58.685757
#  2017-12-31    61.275125
#  Freq: M, Name: forecast, dtype: float64}

# %%
color = ['yellow','blue','red','green']

fig,ax = plt.subplots(1,1,figsize=(20,12))
plt.plot(data,marker='o',color='black',label='Actual sales price')

for i in range(len(alphas)):
    plt.plot(d_simple_exp[alphas[i]],marker='.',color=color[i],label='simple smoothing: alpha='+ str(alphas[i]))

plt.title('Simple Exponent Smoothing')
plt.legend()
plt.show()

# %% [markdown]
# # Double Exponent Smoothing

# %%
model = ExponentialSmoothing(data,trend='additive').fit(smoothing_level=0.2,smoothing_slope=0.5)

f_dexp = model.fittedvalues
print(f_dexp)
# Out:
# date
# 2013-01-31    42.418425
# 2013-02-28    40.777403
# 2013-03-31    39.361765
# 2013-04-30    39.679308
# 2013-05-31    41.644672
# 2013-06-30    44.727935
# 2013-07-31    48.785408
# 2013-08-31    53.111118
# 2013-09-30    55.056955
# 2013-10-31    55.012378
# 2013-11-30    52.984855
# 2013-12-31    51.445120
# 2014-01-31    45.638877
# 2014-02-28    40.073524
# 2014-03-31    36.165182
# 2014-04-30    35.494808
# 2014-05-31    38.099553
# 2014-06-30    42.942482
# 2014-07-31    49.267456
# 2014-08-31    56.451592
# 2014-09-30    60.932890
# 2014-10-31    62.700074
# 2014-11-30    62.063552
# 2014-12-31    61.571601
# 2015-01-31    55.531798
# 2015-02-28    48.381893
# 2015-03-31    42.508515
# 2015-04-30    39.830443
# 2015-05-31    40.762655
# 2015-06-30    44.379304
# 2015-07-31    49.618348
# 2015-08-31    56.429703
# 2015-09-30    60.664868
# 2015-10-31    62.577012
# 2015-11-30    62.301969
# 2015-12-31    62.117502
# 2016-01-31    56.482370
# 2016-02-29    50.146498
# 2016-03-31    45.012992
# 2016-04-30    43.230098
# 2016-05-31    45.314856
# 2016-06-30    49.561886
# 2016-07-31    55.698796
# 2016-08-31    63.442627
# 2016-09-30    67.596952
# 2016-10-31    69.432898
# 2016-11-30    68.716173
# 2016-12-31    67.956433
# 2017-01-31    61.507237
# 2017-02-28    53.584872
# 2017-03-31    47.238305
# 2017-04-30    44.483108
# 2017-05-31    45.992821
# 2017-06-30    49.838362
# 2017-07-31    56.053297
# 2017-08-31    63.897052
# 2017-09-30    68.533466
# 2017-10-31    70.850601
# 2017-11-30    70.397334
# 2017-12-31    70.072888
# Freq: M, dtype: float64

# %%
plt.plot(data,marker='o',color='black',label ='Actual Sales Price')
plt.plot(f_dexp,marker='.',color='red',label='Double Exp smoothing ')
plt.legend()
plt.title('Double Exponent Smoothing')
# Out:
# Text(0.5, 1.0, 'Double Exponent Smoothing')

# %% [markdown]
# # Triple Exponent Smoothing

# %%
model = ExponentialSmoothing(data.values,trend='add',seasonal='add',seasonal_periods=12).fit()
model

# %%
f_texp= model.fittedvalues
f_texp
# Out:
# array([29.3244704 , 33.17947847, 40.78500715, 47.73254246, 49.58785797,
#        53.15830504, 57.01971752, 47.42944895, 45.32027319, 42.07659656,
#        46.36863692, 30.33429085, 31.6483183 , 37.63706591, 45.73400458,
#        53.30282947, 56.60982633, 60.83715947, 64.45095304, 55.95020225,
#        53.03552408, 48.50202081, 52.9584836 , 37.50845862, 36.40302302,
#        39.52117851, 47.33665764, 55.01555966, 58.94270462, 63.64867664,
#        66.51852509, 59.00924341, 55.32719006, 51.03471525, 55.43721507,
#        39.3383095 , 38.30354415, 42.66725108, 50.3742293 , 58.83495935,
#        64.03182378, 67.70003435, 72.12368117, 65.49605467, 59.41316112,
#        55.88844348, 59.7524607 , 43.59534597, 41.94321456, 43.77857325,
#        52.2980066 , 60.87846363, 66.46893572, 69.78302355, 74.88046429,
#        67.64094413, 62.26780177, 58.46718119, 61.57372436, 46.04983712])

# %%
fig,ax = plt.subplots(figsize=(20,10))
plt.plot(data.values,marker='o',color='black',label='Actiual Sales data')
plt.plot(f_texp,marker='.',color='red',label='Triple Exp Smoothing')
plt.legend()

plt.title('Triple Exponent Smoothing');
